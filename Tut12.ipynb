# %%
import pandas as pd
df = pd.read_csv("D:\\Kaustubh Wankhede\\Complete Machine Learning Course\\Pandas Tutorials\\student_results.csv")
df
# Out:
#    Student ID        Date  Class  Study hrs  Sleeping hrs  \
# 0        1001  01-07-2021     10          2             9
# 1        1002  02-07-2021     10          6             8
# 2        1003  03-07-2021     10          3             8
# 3        1004  04-07-2021     11          0            10
# 4        1005  05-07-2021     11          4             7
# 5        1006  06-07-2021     12         10             7
# 6        1007  07-07-2021     13          4             6
# 7        1008  08-07-2021     14         10             6
# 8        1009  09-07-2021     12          2             8
# 9        1010  10-07-2021     12          6             9
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3               5.0          50
# 1                       2               0.0          80
# 2                       2               NaN          60
# 3                       1               NaN          45
# ...

# %%
df.interpolate()
# Out:
#    Student ID        Date  Class  Study hrs  Sleeping hrs  \
# 0        1001  01-07-2021     10          2             9
# 1        1002  02-07-2021     10          6             8
# 2        1003  03-07-2021     10          3             8
# 3        1004  04-07-2021     11          0            10
# 4        1005  05-07-2021     11          4             7
# 5        1006  06-07-2021     12         10             7
# 6        1007  07-07-2021     13          4             6
# 7        1008  08-07-2021     14         10             6
# 8        1009  09-07-2021     12          2             8
# 9        1010  10-07-2021     12          6             9
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3               5.0          50
# 1                       2               0.0          80
# 2                       2               0.0          60
# 3                       1               0.0          45
# ...

# %%
df = pd.read_csv("D:\\Kaustubh Wankhede\\Complete Machine Learning Course\\Pandas Tutorials\\student_results.csv", parse_dates = ["Date"], index_col = "Date")
df
df.interpolate(method = "time")
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2021-01-07        1001     10          2             9
# 2021-02-07        1002     10          6             8
# 2021-03-07        1003     10          3             8
# 2021-04-07        1004     11          0            10
# 2021-05-07        1005     11          4             7
# 2021-06-07        1006     12         10             7
# 2021-07-07        1007     13          4             6
# 2021-08-07        1008     14         10             6
# 2021-09-07        1009     12          2             8
# 2021-10-07        1010     12          6             9
#
#             Social Media usage hrs  Mobile Games hrs  Percantege
# Date
# 2021-01-07                       3               5.0          50
# 2021-02-07                       2               0.0          80
# 2021-03-07                       2               0.0          60
# 2021-04-07                       1               0.0          45
# ...

# %%
df = pd.read_csv("D:\\Kaustubh Wankhede\\Complete Machine Learning Course\\Pandas Tutorials\\student_results.csv", parse_dates = ["Date"], index_col = "Class")
df
df.interpolate(method = "index")
# Out:
#        Student ID       Date  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Class
# 10           1001 2021-01-07          2             9                       3
# 10           1002 2021-02-07          6             8                       2
# 10           1003 2021-03-07          3             8                       2
# 11           1004 2021-04-07          0            10                       1
# 11           1005 2021-05-07          4             7                       2
# 12           1006 2021-06-07         10             7                       0
# 13           1007 2021-07-07          4             6                       0
# 14           1008 2021-08-07         10             6                       2
# 12           1009 2021-09-07          2             8                       2
# 12           1010 2021-10-07          6             9                       1
#
#        Mobile Games hrs  Percantege
# Class
# 10                  5.0          50
# ...

# %%
df.interpolate(method = "nearest")
# Out:
#        Student ID       Date  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Class
# 10           1001 2021-01-07          2             9                       3
# 10           1002 2021-02-07          6             8                       2
# 10           1003 2021-03-07          3             8                       2
# 11           1004 2021-04-07          0            10                       1
# 11           1005 2021-05-07          4             7                       2
# 12           1006 2021-06-07         10             7                       0
# 13           1007 2021-07-07          4             6                       0
# 14           1008 2021-08-07         10             6                       2
# 12           1009 2021-09-07          2             8                       2
# 12           1010 2021-10-07          6             9                       1
#
#        Mobile Games hrs  Percantege
# Class
# 10                  5.0          50
# ...

# %%
df.interpolate(limit = 3)
# Out:
#        Student ID       Date  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Class
# 10           1001 2021-01-07          2             9                       3
# 10           1002 2021-02-07          6             8                       2
# 10           1003 2021-03-07          3             8                       2
# 11           1004 2021-04-07          0            10                       1
# 11           1005 2021-05-07          4             7                       2
# 12           1006 2021-06-07         10             7                       0
# 13           1007 2021-07-07          4             6                       0
# 14           1008 2021-08-07         10             6                       2
# 12           1009 2021-09-07          2             8                       2
# 12           1010 2021-10-07          6             9                       1
#
#        Mobile Games hrs  Percantege
# Class
# 10                  5.0          50
# ...
